# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('accounts.csv')

# %%
df.columns
# Out:
# Index(['Account_ID', 'Customer_ID', 'Account_Type', 'Balance', 'Open_Date',
#        'Status'],
#       dtype='object')

# %%
df1=pd.read_csv('loans.csv')

# %%
df1.columns
# Out:
# Index(['Loan_ID', 'Customer_ID', 'Loan_Type', 'Loan_Amount', 'Interest_Rate',
#        'Loan_Term_Months', 'Default_Status'],
#       dtype='object')

# %%
df2=pd.read_csv('customers.csv')

# %%
df2.columns
# Out:
# Index(['Customer_ID', 'Gender', 'City', 'Income', 'Credit_Score', 'Join_Date'], dtype='object')

# %%
df3=pd.read_csv('credit_cards.csv')
df3.columns
# Out:
# Index(['Card_ID', 'Customer_ID', 'Card_Type', 'Credit_Limit',
#        'Current_Balance', 'Late_Payments'],
#       dtype='object')

# %%
df4=pd.read_csv('transactions.csv')
df4.columns
# Out:
# Index(['Transaction_ID', 'Account_ID', 'Transaction_Date', 'Amount',
#        'Transaction_Type', 'Channel', 'Is_Fraud'],
#       dtype='object')

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Account_ID       0.000000
# Customer_ID      0.000000
# Account_Type    24.851852
# Balance          0.000000
# Open_Date        0.000000
# Status          33.469136
# dtype: float64

# %%
(df1.isnull().sum()/len(df1))*100
# Out:
# Loan_ID              0.000000
# Customer_ID          0.000000
# Loan_Type           23.803279
# Loan_Amount          0.000000
# Interest_Rate        0.000000
# Loan_Term_Months    16.819672
# Default_Status       0.000000
# dtype: float64

# %%
(df2.isnull().sum()/len(df2))*100
# Out:
# Customer_ID      0.000000
# Gender           4.000000
# City            20.613861
# Income          20.277228
# Credit_Score    16.930693
# Join_Date        0.000000
# dtype: float64

# %%
(df3.isnull().sum()/len(df3))*100
# Out:
# Card_ID             0.000000
# Customer_ID         0.000000
# Card_Type          25.061728
# Credit_Limit        0.000000
# Current_Balance     0.000000
# Late_Payments      21.012346
# dtype: float64

# %%
df4.isnull().sum()
# Out:
# Transaction_ID          0
# Account_ID              0
# Transaction_Date        0
# Amount                  0
# Transaction_Type    50288
# Channel             50123
# Is_Fraud                0
# dtype: int64

# %%
(df4.isnull().sum()/len(df4))*100
# Out:
# Transaction_ID       0.000000
# Account_ID           0.000000
# Transaction_Date     0.000000
# Amount               0.000000
# Transaction_Type    25.081297
# Channel             24.999002
# Is_Fraud             0.000000
# dtype: float64
